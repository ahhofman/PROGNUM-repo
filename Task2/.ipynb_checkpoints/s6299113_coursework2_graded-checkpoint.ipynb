# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: ..........
# * Username: ..........
# * Student number: ..........
# * Group (AS1, etc.): ..........
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * Upload your JD.py to your GitHub account -- ``PROGNUM-repo``, and set your account to be public. In your answer, provide your GitHub repository link.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %%
# Calculating the Julian Date

import math

D = float(input("What is the day?"))
M = float(input("What is the month?"))
Y = float(input("What is the year?"))

JD = 367*Y -7*(Y+(M+9)//12)//4 - 3*((Y+(M-9)//7)//100 + 1)//4 + (275*M)//9 + D + 1721029-0.5
print(f"The Julian Date corresponding to the date you input is {JD}")
# Out:
# What is the day? 1
# What is the month? 1
# What is the year? 1
# The Julian Date corresponding to the date you input is 1721425.5

# %% [markdown]
# Link to my Github repository:
# https://github.com/ahhofman/PROGNUM-repo

# %% [markdown]
# ![image.png](attachment:4e5d8a59-237e-4fc6-b017-d87abe0e9036.png)

# %%
# Number of days between two dates

import math


# The first date

D1 = float(input("First insert the first date. What is the day?"))
M1 = float(input("What is the month?"))
Y1 = float(input("What is the year?"))


# The second date

D2 = float(input("Now insert the second date. What is the day?"))
M2 = float(input("What is the month?"))
Y2 = float(input("What is the year?"))


# Number of days between the two dates

nd = (367*Y2 -7*(Y2+(M2+9)//12)//4 - 3*((Y2+(M2-9)//7)//100 + 1)//4 + (275*M2)//9 + D2 + 1721029-0.5)-(367*Y1 -7*(Y1+(M1+9)//12)//4 - 3*((Y1+(M1-9)//7)//100 + 1)//4 + (275*M1)//9 + D1 + 1721029-0.5)

print(f"The number of days between {D1}/{M1}/{Y1} and {D2}/{M2}/{Y2} is {nd}")
# Out:
# First insert the first date. What is the day? 1
# What is the month? 1
# What is the year? 1
# Now insert the second date. What is the day? 1
# What is the month? 1
# What is the year? 1
# The number of days between 1.0/1.0/1.0 and 1.0/1.0/1.0 is 0.0

# %% [markdown]
# My age expressed in days is 9796 days.

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 4

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
import math
import cmath

# Variables a, b, c

a = float(input("What's the value of a?"))
b = float(input("What's the value of b?"))
c = float(input("What's the value of c?"))


# Calculating d

d = b**2-4*a*c


# Calculating the solutions depending on the value of d

if d > 0:
    x1 = (-b+((d)**(1/2)))/(2*a)
    x2 = (-b-((d)**(1/2)))/(2*a)
    print(f"The roots of f(x) are {x1} and {x2}.")
elif d==0:
    x3 = (-b+((d)**(1/2)))/(2*a)
    print(f"The root of f(x) is {x3}.")
else:
    x4 = (-b+cmath.sqrt(d))/(2*a)
    x5 = (-b-cmath.sqrt(d))/(2*a)
    print(f"The roots of f(x) are {x4} and {x5}.")
# Out:
# What's the value of a? 1
# What's the value of b? 1
# What's the value of c? 1
# The roots of f(x) are (-0.5+0.8660254037844386j) and (-0.5-0.8660254037844386j).

# %% [markdown]
# ![image.png](attachment:019acb1d-93e6-46ba-ade4-4ed7488a631b.png)

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 3

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

s1 = set(night1)
s2 = set(night2)


#Values that are both in night 1 and night 2

res1 = list(s1.intersection(s2))
print(f"The common numbers between night 1 and night 2 are {res1}")


# Values that are different between night 1 and night 2

res2 = list(s1.difference(s2))
print(f"The list night 2 subtarcted from the list night 2 is {res2}")


# Values that appear in both sets without duplicates

res3 = list(s1.union(s2))
print(f"The common elements of list night 1 and night 2 are {res3}")


# Updated night 1 list to contain only elemets also available in night 2

night1.remove(5)
night1.remove(7)
night1.remove(9)
print(f"The update of list night 1 containing only elements available both in night 1 and night 2 is: {night1}")
# Out:
# The common numbers between night 1 and night 2 are [0, 1, 2, 3, 4]
# The list night 2 subtarcted from the list night 2 is [9, 5, 7]
# The common elements of list night 1 and night 2 are [0, 1, 2, 3, 4, 5, 7, 9]
# The update of list night 1 containing only elements available both in night 1 and night 2 is: [1, 3, 2, 4, 0, 3, 2, 2, 4, 3]

# %% [markdown]
# <div class="warning" style='background-color:#FFF2CF; color: #C16310; border-left: solid #EA9F27 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>⚠️</span> WARNING</b><br><br>
#     The last question should've been done differently, as we wanted to see it in a list form after the set, so no repeating numbers <b>[0.5pt deducted from total points]</b>

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 1.5

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
import math

planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }


# List with only names of the planets

planets = list(planetsmass.keys())
print(f"The names of the planets are: {planets}")


# Mass of Venus in Earth masses

masses = list(planetsmass.values())
massV = masses[1]/masses[2]
print(f"The mass of Venus is {massV} Earth masses.")


# Removing Pluto from the dictionary

del planetsmass['Pluto']


# Adding Planet Nine to the dictionary

planetsmass['Planet Nine']  = 29.3

print(planetsmass)
# Out:
# The names of the planets are: ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune', 'Pluto']
# The mass of Venus is 0.81438127090301 Earth masses.
# {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100, 'Planet Nine': 29.3}

# %% [markdown]
# <div class="warning" style='background-color:#C9E4FD; color: #004280; border-left: solid #0363BC 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>ℹ️</span> INFORMATION</b><br><br>
#     You could also use planetsmass["Venus"] to extract it, instead of making it a list and finding it manually. That is the whole purpose of the keys in a dictionary

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 2

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import math
import scipy.constants
import numpy as np
from scipy.constants import pi


# Array with 100 angles in degrees between 0 and 360

x = np.linspace(0,360,100)


# Array x in radians

x2 = np.radians(x)


# Sinc of values of x in radians

x3 = np.sinc(x2)


# Printing the first 10 values

for i in range(10):
    print(x3[i])
    i = i + 1
# Out:
# 1.0
# 0.9933873652026526
# 0.9737067586290185
# 0.9414256204351539
# 0.8973083104869668
# 0.842394523762147
# 0.7779700080257624
# 0.705530483396262
# 0.6267398696896891
# 0.5433840979844083

# %% [markdown]
# <div class="warning" style='background-color:#FFF2CF; color: #C16310; border-left: solid #EA9F27 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>⚠️</span> WARNING</b><br><br>
#     Incorrect length of the first 10 values, also preferablly use a mask <b>[0.5pt deducted from total points]</b>

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 1.5

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 13. Student score: 12.0.  Task Grade = 9.2
