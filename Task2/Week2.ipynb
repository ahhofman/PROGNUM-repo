# %% [markdown]
# Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# Question 2.1
#
# $$E = hc / \lambda$$

# %% [markdown]
# Question 2.2
#
# $$F = G \frac{m_{1} m_{2}}{r^2}$$

# %% [markdown]
# Question 2.5
#
# $$ \displaystyle\sum_{k=0}^{\infty} \frac{1}{4 k^2 - 1} = \frac{1}{2}$$
#
# $$ \int_0^\infty \mathrm{e}^{ix}\, \mathrm{d}x = 2i $$

# %%
#Question 2.9

from math import factorial

result = factorial(100)

print("The factorial of 100 is", result)
# Out:
# The factorial of 100 is 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
#Question 2.11

from math import atan2

y = 3
x = 2
a = atan2(y, x)

print("The angle a is", a)
# Out:
# The angle a is 0.982793723247329

# %%
#Question 2.12

from math import atan2, degrees

x = float(input('What is the x value: '))
y = float(input('What is the y value: '))

angle = atan2(y, x)
ad = degrees(angle)  #Angle in degrees

if 0 < ad < 90 :
    print(f"The point {x, y} belongs to the first quadrant and it makes the angle {ad} with the x axis")
elif 90 < ad < 180 :
    print(f"The point {x, y} belongs to the second quadrant and it makes the angle {ad} with the x axis")
elif -180 < ad < -90 :
    print(f"The point {x, y} belongs to the third quadrant and it makes the angle {ad} with the x axis")
else :
    print(f"The point {x, y} belongs to the fourth quadrant and it makes the angle {ad} with the x axis")
# Out:
# What is the x value: -1
# What is the y value: 2
# The point (-1.0, 2.0) belongs to the second quadrant and it makes the angle 116.56505117707799 with the x axis

# %%
# Question 2.14

X = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]

X.append (0.51)
X.remove (2.12)

#The value 1.97 has index 6. The value 1.46 has index 1.

s = slice (2, 8, 2)  #Modyfied list

print("The modyfied list is", X[s])

res = sum(X[s])

print("The sum of the modyfied list is", res)
# Out:
# The modyfied list is [1.41, 0.98, 1.97]
# The sum of the modyfied list is 4.359999999999999

# %%
# Question 2.15

night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

s1 = set(night1)
s2 = set(night2)

res = s1.intersection(s2)

yomom = list(res)

print("The elements in common are", yomom)

if 5 in res :
    print("5 is a common element")
else :
    print("5 is not a common element")
    
if 5 in s1:
    print("yay 5 is in set of night 1 hurrayyyyyyyyy")
else:
    print("on noooo there is no 5 in s1")
# Out:
# The elements in common are [0, 1, 2, 3, 4]
# 5 is not a common element
# yay 5 is in set of night 1 hurrayyyyyyyyy

# %%
# Question 2.19

import array as ar
import numpy as np

mu, sigma = 0.0, 1.4
x = np.random.normal(mu, sigma, size=1000)
array = np.array(x)

std = np.std(x)

print("The standard deviation is:", std)
# Out:
# The standard deviation is: 1.3945690810888627

# %%
# Question 2.21

x = 1
y = 2

for i in range(98):
    z = x + y
    x = y
    y = z
print(z)
# Out:
# 573147844013817084101

# %% [markdown]
# Question 2.26
#
# ![Screenshot%20from%202026-02-18%2017-03-46.png](attachment:Screenshot%20from%202026-02-18%2017-03-46.png)
