# %% [markdown]
# # Coursework Set week 4

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: Adrian Hofman
# * Username: ahhofman
# * Student number: s6299113
# * Group (AS1, etc.): AS3
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Monte Carlo Error Propagation (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# One of the classical Physic Lab experiment is to use pendulum to calculate the local gravitational acceleration, ``g``, from the measurements of the pendulum length ``L`` and the oscillation period ``T``.
#
# The formula is expressed as follows:
#
# $$ g=\frac{4\pi^2 L}{T^2} $$
#
# You have got a set of measurements of $L=1.00\pm0.01\ \mathrm{(m)}$ and $T=2.01\pm0.02\ \mathrm{(s)}$.
#
# * Like in Physics Lab, use Tyler expansion described above to propagate the error. Write your derivation in Markdown.
#
# * Calculate the error of the derived ``g``.
#
# * Apply Monte Carlo error propagation to estimate the value and uncertainty of ``g``.
#
# * Make appropriate comments.
#
# * Compare the two results.

# %% [markdown]
# $$ \Delta g = \sqrt(\frac{\partial g}{\partial L} \Delta L)^2+(\frac{\partial g}{\partial T} \Delta T)^2) = \sqrt(\frac{4 \pi^2}{T^2}\Delta L)^2 + (\frac{8\pi^2L}{T^3} \Delta T)^2 = \sqrt(\frac{4 \pi^2}{2.01^2}(0.01))^2 + (\frac{8\pi^2}{2.01^3}(0.02))^2$$

# %%
import math
from math import pi
import numpy as np

# Calculating the error in g using taylor excpanssion

delta_g = math.sqrt(((4*0.01*pi**2)/(2.01**2))**2+((-8*0.02*pi**2)/(2.01**3))**2)
print(delta_g)

# Monte Carlo error propagation

# Generating a sample of values for L and T

L = np.random.normal(loc = 1, scale = 0.01, size = 1000)
T = np.random.normal(loc = 2.01, scale = 0.02, size = 1000)

# Calculating g from those values

g = (4*L*pi**2)/(T**2)

# Calculating the mean (value) and standard deviagtion (uncertainity) of g

meang = np.mean(g)
errorg = np.std(g)

print(f"The estimated value of g is {meang} +- {errorg}")

# The two results are very similar which suggests they're good approximations.
# Out:
# 0.21763137533582413
# The estimated value of g is 9.770295656603327 +- 0.21182009430483387

# %% [markdown]
# <div class="warning" style='background-color:#FFF2CF; color: #C16310; border-left: solid #EA9F27 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>⚠️</span> WARNING</b><br><br>
#     You did not rerun your code as otherwise you would've caught this error. You can redo this in the correction but now you will not obtain points. Just a note of help, the code looks good further, maybe just increase the sample size in part 2.

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0.0

# %% [markdown]
# ### Complex roots of a quadratic equation (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use the information in the notebook about complex numbers to write a program that can calculate the (complex) roots of a quadratic equation with the quadratic formula:
#
# $$ y=ax^2+bx+c $$
#
# The requirement of this program is as follows:
#
# * User can supply constants ``a``, ``b`` and ``c`` with Python function `input()`.
# * The program can deal with complex roots.
# * Your program must print the equation with its constants and its roots.
# * The solutions must be inserted to the original equation to prove that $f(x)=0$.
#
# **Answer**:

# %%
# import math
import cmath

# Variables a, b, c

a = float(input("What's the value of a?"))
b = float(input("What's the value of b?"))
c = float(input("What's the value of c?"))


# Calculating d

d = b**2-4*a*c

# Calculating the solutions depending on the value of d

if d >= 0:
    x1 = (-b+((d)**(1/2)))/(2*a)
    x2 = (-b-((d)**(1/2)))/(2*a)
    print(f"The roots of f(x)={a}*x**2 + {b}*x+ {c} are {x1} and {x2}.")
    res1 = a*x1**2 + b*x1 + c
    res2 = a*x2**2 + b*x2 + c
    print(f" f({x1}) = {res1}, f({x2}) = {res2}")
elif d==0:
    x3 = (-b+((d)**(1/2)))/(2*a)
    res3 = a*x3**2 + b*x3 + c
    print(f"The root of f(x)={a}*x**2 + {b}*x+ {c} is {x3}.")
    print(f" f({x3}) = {res3}")
else:
    x4 = (-b+cmath.sqrt(d))/(2*a)
    x5 = (-b-cmath.sqrt(d))/(2*a)
    print(f"The roots of f(x)={a}*x**2 + {b}*x+ {c} are {x4} and {x5}.")
    res4 = a*x4**2 + b*x4 + c
    res5 = a*x5**2 + b*x5 + c
    print(f" f({x4}) = {res4}, f({x5}) = {res5}")

# When the roots are complex substituting them back into the function the result is not zero due to rounding errors.
# Out:
# What's the value of a? 1
# What's the value of b? 2
# What's the value of c? 1
# The roots of f(x)=1.0*x**2 + 2.0*x+ 1.0 are -1.0 and -1.0.
#  f(-1.0) = 0.0, f(-1.0) = 0.0

# %% [markdown]
# <div class="warning" style='background-color:#C9E4FD; color: #004280; border-left: solid #0363BC 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>ℹ️</span> INFORMATION</b><br><br>
#     Your code works, but it can be made way shorter, if you use the code of the else function it should also just work!

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 4

# %% [markdown]
# ### Area under a Gaussian (6 pt) <font color='red'><b>COURSEWORK</b></font>
#
# A one dimensional Gaussian function is given by:
#
# $$f(x) = A\ e^{\frac{-{(x-x_0)}^2}{2 \sigma^2}} + z_0$$
#
# $A$ is the amplitude, $x_0$ is the position of the peak, $\sigma$ is the width of the peak
# and $z_0$ is the offset in $y$.
#
# This function can be written in Python as follows:
#
# ```python
# def gauss(x, A, x0, sigma, z0):
#     return A*np.exp(-(x-x0)**2/(2*sigma**2))+z0
# ```
#
# 1. Set in the calling environment:
# ```python
#     A = 1.0
#     x0 = 0.0
#     sig = 2.0
#     z0 = 0.0
# ```
# 2. Plot this function between -10 and 10 with 200 samples.
# 3. Use function `scipy.integrate.quad()` to find the area between ``x=0`` and ``x=2.5``.
# 4. Use function `matplotlib.pyplot.fill_between()` to mark that area in your plot.
# 5. Calculate the area between $-\infty$ and $\infty$ ($\approx 5.01$).
# 6. Given is the integral for the total area under the curve:
#
#     $$\int _{-\infty }^{\infty }Ae^{-(x-x_0)^{2}/(2\sigma^{2})}\,\mathrm{d}x=A \sigma \cdot {\sqrt {2\pi }}$$
#
#    Calculate this area for the values of the parameters given above and prove with ``quad()`` that the two are the same.
#
# 7. Make the last part an executable script, called ``gaussarea``. The user can enter values for ``A``, ``x0``, ``sig`` and ``z0`` and the integration limits. The programme then calculates the area under the curve between the integration limits using function ``quad()``. The programme must includes a plot of the curve, the integration area, and the value of that area in a legend.
# 8. Insert the generated plot in a separate markdown cell below your code cell, and upload your script to GitHub. Provide your GitHub website link in the notebook too for TA to check.
#
# **Answers**:

# %%
import math
import numpy as np
import scipy
import matplotlib.pyplot as plt

# Setting the calling envorinemnt

A = 1.0
x0 = 0.0
sigma = 2.0
z0 = 0.0

def gauss(x, A, x0, sigma, z0):
    return A*np.exp(-(x-x0)**2/(2*sigma**2))+z0

# Plotting the function between -10 and 10

x = np.linspace(-10,10,200)
plt.plot(x, gauss(x, A, x0, sigma, z0))


# Finding the area between x=0 and x=2.5

area, error = scipy.integrate.quad(lambda x: A*np.exp(-(x-x0)**2/(2*sigma**2))+z0, 0, 2.5)
print(area)

# Marking that area on the graph

plt.fill_between(x, gauss(x, A, x0, sigma, z0), where=(x >= 0) & (x <= 2.5), color = 'green', alpha = 0.4)
plt.show

# Calcualting the area under the graph (from minus infinity to infinity)

# Approximation

Area = A * sigma * math.sqrt(2*math.pi)

# Scipy

Area2, error2 = scipy.integrate.quad(lambda x: A*np.exp(-(x-x0)**2/(2*sigma**2))+z0, -np.inf, np.inf)

print(f"The area under the graps is {Area} using the approximation and {Area2} using scipy.")
# Out:
# 1.9769788548675902
# The area under the graps is 5.0132565492620005 using the approximation and 5.013256549262001 using scipy.

# %% [markdown]
# ![Screenshot 2026-03-14 at 14.06.31.png](attachment:bc06adfa-3544-4efa-8950-22a86701b3a2.png)

# %% [markdown]
# Link to my Github repo where you can find the executable script: https://github.com/ahhofman/PROGNUM-repo/tree/main/Task4

# %% [markdown]
# <div class="warning" style='background-color:#FFF2CF; color: #C16310; border-left: solid #EA9F27 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>⚠️</span> WARNING</b><br><br>
#     We do not use a scatter plot for a line such as a Gaussian, use the normal plt.plot for this <b>[0.5pt deducted from total points]</b>

# %%
# Leave unaltered
totalpoints += 6
currentpoints += 5.5

# %% [markdown]
# ### Calculate integral of a user supplied function (6 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Write a programme that calculates the integral of any function from the user input using ``eval()``, which is a string representing a function and a variable (floating number) for which the function will be evaluated.
#
# * Call from ``numpy import sin, cos, exp, pi`` to apply these functions and constants in your code.
# * Use ``scipy.integrate.quad()`` to calculate the integral of the formula below between $x=0$ and $x=\pi$
# * Use Monte Carlo Integration to calculate the integral of the formula below for $x=0$ and $x=\pi$
#
# $$ f(x)=x^4+e^{\sin{x}+\cos{x}} $$
#
# Make the function robust with try/except clauses. Demonstrate exceptions for wrong expressions and unknown functions in an expression (NameError) etc. Print messages that tell a user what they have done wrong!
#
# Make the above code an executable script called ``interate_user_function``, and upload to GitHub.
#
# * Create a separate cell, and use SymPy expression to calculate the integral of the formula below for $x=0$ and $x=\pi$.

# %%
import math
import numpy as np
from numpy import sin, cos, exp, pi
import scipy

while True:
   try:
       fun = input("Enter a function f(x)=")
       a = eval(input("Lower bound:"))
       b = eval(input("Upper bound:"))
       n = int(input("Number of data points:"))
       x = np.random.uniform(a, b, n)
       y = eval(fun, {"x": x, "sin": sin, "cos": cos, "exp": exp, "pi": pi, "np": np})
       int_ = ((b-a)/n)*np.sum(y)     
       print(f"The intergral of {fun} from {a} to {b} using Monte Carlo integration is {int_}.")
       break
   except TypeError:
      print("Wrong object type for this value")
   except NameError:
       print("This variable was not defined")
   except ValueError:
       print("The value is wrong")
   except ZeroDivisionError:
       print("Can't divide by zero")
   except SyntaxError:
       print("The syntax is wrong")

# Scipy integrate

res, error = scipy.integrate.quad(lambda x: x**4+exp(sin(x)+cos(x)), 0, pi)
print(f"The intergral of x**4+exp(sin(x)+cos(x)) from 0 to 3.141592653589793 using scipy is {res}.")
# Out:
# Enter a function f(x)= x
# Lower bound: 1
# Upper bound: 2
# Number of data points: 2000
# The intergral of x from 1 to 2 using Monte Carlo integration is 1.4884321184843192.
# The intergral of x**4+exp(sin(x)+cos(x)) from 0 to 3.141592653589793 using scipy is 68.72932272689113.

# %%
import sympy as sp

x = sp.symbols('x')
int = sp.N(sp.integrate(x**4, (x, 0, pi)) + sp.integrate(sp.exp(sp.sin(x)+sp.cos(x)), (x, 0, pi)))
print(f" The integral is: {int}")
# Out:
#  The integral is: 68.7293227268911

# %% [markdown]
# <div class="warning" style='background-color:#FFF2CF; color: #C16310; border-left: solid #EA9F27 6px; border-radius: 4px; padding:2em;'>
# <span>
# <b><span style='font-size: 150%;'>⚠️</span> WARNING</b><br><br>
#     The integral given in the question is also needed in the monte carlo approach <b>[0.5pt deducted from total points]</b><br>
#     Sympy needs to give a numerical answer, not this thingy <b>[1pt deducted]</b>

# %%
# Leave unaltered
totalpoints += 6
currentpoints += 4.5
#We needed the last integral also with Monte carlo -0.5
#Sympy doesn't give a definite value -1

# %% [markdown]
# ### Plotting Hertzsprung–Russell (HR) diagram (6 pt) <font color='red'><b>COURSEWORK</b></font>
#
# ``Hertzsprung-Russell (HR) diagram``, which indicates the stellar evolution, is an important astrophysical plot graphing stellar luminosity (brightness, absolute magnitude) against surface temperature (or colour). This diagram clearly states the evolutionary pathways of stars and where they are in their lifetime. With this, we classify several important stages of a star's life -- main sequence stars, giants, or white dwarfs.
#
# In this exercise, a combined APOGEE/Gaia star catalog has been prepared for you to create an HR diagram -- download the catalogue from the BrightSpace: ``APOGEE+Gaia_stars.fits``
#
# * To read FITS file, you need AstroPy, which is a library that is widely used in Astronomy.
#
# ```python
# from astropy.io import fits
#
# # Open the FITS file
# hdul = fits.open('APOGEE_stars.fits')
#
# # Access the primary data (in this case, it is a Table)
# data = hdul[1].data  # Often, the first extension contains the table
# colnames = hdul[1].columns.names # List of the column names
# ```
#
# * "data" is a AstroPy data class, but it can be used like a ndarray as follows.
#
# ```python
# print(data[0]) # The first row of the catalogue
# print(data['STARFLAG']) # List all rows in the column of "STARFLAG"
# print(data['STARFLAG'][:10]) # Print the first 10 elements in the column of "STARFLAG"
# print(data['STARFLAG'][-10:]) # Print the last 10 elements in the column of "STARFLAG"
# ```
#
# * Firstly, let's select data with good quality and robust measurements using the following criteria:
#     * STARFLAG == 0
#     * ASPCAPFLAG == 0
#     * SNR > 10
#     * GAIAEDR3_PARALLAX/ GAIAEDR3_PARALLAX_ERROR > 5
#     * GAIAEDR3_PHOT_G_MEAN_MAG is not NaN value
#     * GAIAEDR3_PHOT_BP_MEAN_MAG is not NaN value
#     * GAIAEDR3_PHOT_RP_MEAN_MAG is not NaN value
#
# * From the selected data, let's randomly choose about **80% of the data** for plotting the HR diagram.
#
# * The HR diagram contains
#     * $x$-axis: colour -- BP-RP
#     * $y$-axis: absolute magnitude -- $M_G$
#
#
# **<span style="color:red">Warning</span>**: note that from observation, we only have apparent magnitude (i.e. observed magnitude). To convert into absolute magnitude requires **Distance Modulus**:
#
# $$ M_G = m_G + 5\log10{(\mathrm{parallax}/1000)} + 5 $$
#
# * Apply a rough binary classification scheme to separate giant branch and main sequence (MS) stars.
#     * Giant branch: $ M_G<3.5 $ and $(BP-RP)>0.8$
#     * MS: assume the rest of the data is MS
#
# * It seems that we do not have sufficient samples in the White Dwarf (WD) region. Use the following criteria to draw vertical and horizontal lines, as well as define a box indicating the location of WD on the HR diagram.
#     * $(BP-RP)\leq0.8$ and $ M_G>10 $ (very faint)
#
# * Make a scatter plot and customise it to be look like the plot shown here.
#
# <img src="attachment:14037eb3-1593-4349-8d4a-ae0bd96b6e97.png" alt="HR Diagram" width="600">

# %%
from astropy.io import fits
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib import patches


# Open the FITS file
hdul = fits.open('APOGEE_stars.fits')

# Access the primary data (in this case, it is a Table)
data = hdul[1].data  # Often, the first extension contains the table
colnames = hdul[1].columns.names # List of the column names

# Selecting the specific data

mask = (data['STARFLAG'] == 0) & (data['ASPCAPFLAG'] == 0) & (data['SNR'] > 10) & (data['GAIAEDR3_PARALLAX'] / data['GAIAEDR3_PARALLAX_ERROR'] > 5) & (~np.isnan(data['GAIAEDR3_PHOT_G_MEAN_MAG'])) & (~np.isnan(data['GAIAEDR3_PHOT_BP_MEAN_MAG'])) & (~np.isnan(data['GAIAEDR3_PHOT_RP_MEAN_MAG']))
newdata = data[mask]

# Randomly choosing 80% of data

truedata = np.random.choice(newdata, round(len(newdata)*0.8))

# Setting the data for thre x and y axis

x = truedata['GAIAEDR3_PHOT_BP_MEAN_MAG'] - truedata['GAIAEDR3_PHOT_RP_MEAN_MAG']
y = truedata['GAIAEDR3_PHOT_G_MEAN_MAG'] + 5*np. log10(truedata['GAIAEDR3_PARALLAX']/1000) + 5

# Plotting the HR diagram

mask_red = (x > 0.8) & (y < 3.5)

plt.scatter(x[mask_red], y[mask_red], color = 'red', label = 'Giant Branch') # giant branch
plt.scatter(x[~mask_red], y[~mask_red], label = 'MS') # main sequence
plt.gca().invert_yaxis()
a = patches.Rectangle((0.8,10), -0.8, 5, color='grey', alpha=0.3, label = 'White Dwarf Region') # white dwarf region
plt.gca().add_patch(a)
plt.text(0.15, 12.25, "WD", fontsize=14)
plt.ylim(14, -5)
plt.xlim(-0.5, 8)
plt.xlabel("BP - RP", fontsize = 14)
plt.ylabel("Mg", fontsize = 14)
plt.title("HR Diagram", fontsize = 16)
plt.legend(loc='lower right')

# Arrows
plt.annotate(
    r'MS',
    xy=(5,5),
    xytext=(7, 4.5),
    color='blue',
    fontsize=14,
    arrowprops=dict(facecolor='blue', shrink=0.05, width=3, headwidth=12, headlength=10))

plt.annotate(
    r'Giant Branch',
    xy=(5,-1.0),
    xytext=(5.5, -3.0),
    color='red',
    fontsize=14,
    arrowprops=dict(facecolor='red', shrink=0.05, width=3, headwidth=12, headlength=10))

plt.show

# %%
# Leave unaltered
totalpoints += 6
currentpoints += 6

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 26. Student score: 20.0.  Task Grade = 7.7
